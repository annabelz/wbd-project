# %% [markdown]
# NLP Processing

# %%
# !pip install --upgrade pip
# !pip install re
# !pip install typer
# !pip install spacy
# !pip install scispacy
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.

# %%
import pandas as pd
import spacy

# %%
import pandas as pd

# Load your file
disease_chems = pd.read_csv('/home/giannis-charalampopoulos/M2PHDS/web based data/wbd-project/CTD_disease_chems_curated.csv')

# Split the PubMedIDs column into lists
disease_chems['PubMedIDs'] = disease_chems['PubMedIDs'].astype(str).str.split('|')

# Explode into multiple rows
disease_chems = disease_chems.explode('PubMedIDs')

# Reset index (optional)
disease_chems = disease_chems.reset_index(drop=True)

# View result
disease_chems.head()
# Out:
#         # Input       ChemicalName ChemicalID      CasRN  \
# 0  mesh:d002659  succinyladenosine    C043565  4542-23-8
# 1  mesh:d002659  succinyladenosine    C043565  4542-23-8
# 2  mesh:d002659  succinyladenosine    C043565  4542-23-8
# 3  mesh:d002659  succinyladenosine    C043565  4542-23-8
# 4  mesh:d002659  succinyladenosine    C043565  4542-23-8
#
#                          DiseaseName     DiseaseID  \
# 0  Adenylosuccinate lyase deficiency  MESH:C538235
# 1  Adenylosuccinate lyase deficiency  MESH:C538235
# 2  Adenylosuccinate lyase deficiency  MESH:C538235
# 3  Adenylosuccinate lyase deficiency  MESH:C538235
# 4  Adenylosuccinate lyase deficiency  MESH:C538235
#
#                                    DiseaseCategories  OmimIDs PubMedIDs  \
# 0  Genetic disease (inborn)|Mental disorder|Metab...      NaN  10888601
# 1  Genetic disease (inborn)|Mental disorder|Metab...      NaN  10958654
# 2  Genetic disease (inborn)|Mental disorder|Metab...      NaN  17485188
# 3  Genetic disease (inborn)|Mental disorder|Metab...      NaN  18368630
# 4  Genetic disease (inborn)|Mental disorder|Metab...      NaN  23055421
#
#      DirectEvidence
# 0  marker/mechanism
# 1  marker/mechanism
# 2  marker/mechanism
# 3  marker/mechanism
# 4  marker/mechanism

# %%
disease_chems
# Out:
#           # Input       ChemicalName ChemicalID        CasRN  \
# 0    mesh:d002659  succinyladenosine    C043565    4542-23-8
# 1    mesh:d002659  succinyladenosine    C043565    4542-23-8
# 2    mesh:d002659  succinyladenosine    C043565    4542-23-8
# 3    mesh:d002659  succinyladenosine    C043565    4542-23-8
# 4    mesh:d002659  succinyladenosine    C043565    4542-23-8
# ..            ...                ...        ...          ...
# 875  mesh:d001321       Vitamin B 12    D014805      68-19-9
# 876  mesh:d001321        Vitamin B 6    D025101    8059-24-3
# 877  mesh:d001321        Vitamin B 6    D025101    8059-24-3
# 878  mesh:d001321               Zinc    D015032    7440-66-6
# 879  mesh:d001321        ziprasidone    C092292  146939-27-7
#
#                            DiseaseName     DiseaseID  \
# 0    Adenylosuccinate lyase deficiency  MESH:C538235
# 1    Adenylosuccinate lyase deficiency  MESH:C538235
# 2    Adenylosuccinate lyase deficiency  MESH:C538235
# 3    Adenylosuccinate lyase deficiency  MESH:C538235
# 4    Adenylosuccinate lyase deficiency  MESH:C538235
# ..                                 ...           ...
# 875                  Autistic Disorder  MESH:D001321
# 876                  Autistic Disorder  MESH:D001321
# 877                  Autistic Disorder  MESH:D001321
# 878                  Autistic Disorder  MESH:D001321
# 879                  Autistic Disorder  MESH:D001321
#
#                                      DiseaseCategories  OmimIDs PubMedIDs  \
# 0    Genetic disease (inborn)|Mental disorder|Metab...      NaN  10888601
# 1    Genetic disease (inborn)|Mental disorder|Metab...      NaN  10958654
# 2    Genetic disease (inborn)|Mental disorder|Metab...      NaN  17485188
# 3    Genetic disease (inborn)|Mental disorder|Metab...      NaN  18368630
# 4    Genetic disease (inborn)|Mental disorder|Metab...      NaN  23055421
# ..                                                 ...      ...       ...
# 875                                    Mental disorder      NaN  24676906
# 876                                    Mental disorder      NaN  16494569
# 877                                    Mental disorder      NaN  16846101
# 878                                    Mental disorder      NaN  28569757
# 879                                    Mental disorder      NaN  18315450
#
#                    DirectEvidence
# 0                marker/mechanism
# 1                marker/mechanism
# 2                marker/mechanism
# 3                marker/mechanism
# 4                marker/mechanism
# ..                            ...
# 875              marker/mechanism
# 876  marker/mechanism|therapeutic
# 877  marker/mechanism|therapeutic
# 878              marker/mechanism
# 879                   therapeutic
#
# [880 rows x 10 columns]

# %%
pmid_list=disease_chems['PubMedIDs'].astype(str).tolist()

# %%
import requests
import time
import pandas as pd
from xml.etree import ElementTree as ET

# Your list of PMIDs
pmid_list = list(set(pmid_list))  # remove duplicates
total = len(pmid_list)

def fetch_pubmed_xml(pmid):
    """Fetch a single PubMed record via NCBI EFetch."""
    url = (
        "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"
        f"?db=pubmed&id={pmid}&retmode=xml"
    )

    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch {pmid}")
        return None

    return response.text

records = []
for idx, pmid in enumerate(pmid_list, start=1):

    xml_data = fetch_pubmed_xml(pmid)
    if xml_data is None:
        print(f"❌ Could not retrieve PMID {pmid} ({idx}/{total})")
        continue

    # Parse XML
    root = ET.fromstring(xml_data)
    title = root.findtext(".//ArticleTitle")
    abstract = " ".join(
        [t.text for t in root.findall(".//AbstractText") if t.text]
    )

    records.append({
        "pmid": pmid,
        "title": title,
        "abstract": abstract,
        "xml_raw": xml_data
    })

    # Print progress for every PMID found
    print(f"✔️  Retrieved {idx}/{total} → PMID {pmid}")

    # Optional milestone print every 25 items
    if idx % 25 == 0:
        print(f"⏳ Progress: {idx}/{total} ({100*idx/total:.1f}%)")

    # polite delay (NCBI recommends <10 req/sec)
    time.sleep(0.15)

print("DONE! All available PMIDs retrieved.")
df = pd.DataFrame(records)
print("Total records downloaded:", len(df))

df.head()
# Out:
# ✔️  Retrieved 1/208 → PMID 20562626
# ✔️  Retrieved 2/208 → PMID 3709993
# ✔️  Retrieved 3/208 → PMID 35254616
# ✔️  Retrieved 4/208 → PMID 30816183
# ✔️  Retrieved 5/208 → PMID 36113784
# ✔️  Retrieved 6/208 → PMID 17690064
# ✔️  Retrieved 7/208 → PMID 30404997
# ✔️  Retrieved 8/208 → PMID 25290267
# ✔️  Retrieved 9/208 → PMID 25641946
# ✔️  Retrieved 10/208 → PMID 18582451
# ✔️  Retrieved 11/208 → PMID 19997080
# ✔️  Retrieved 12/208 → PMID 15782081
# ✔️  Retrieved 13/208 → PMID 20468076
# ✔️  Retrieved 14/208 → PMID 25423485
# ✔️  Retrieved 15/208 → PMID 19154706
# ✔️  Retrieved 16/208 → PMID 29510222
# ✔️  Retrieved 17/208 → PMID 32479765
# ✔️  Retrieved 18/208 → PMID 15238991
# ✔️  Retrieved 19/208 → PMID 15491979
# ✔️  Retrieved 20/208 → PMID 15319018
# ✔️  Retrieved 21/208 → PMID 32353786
# ✔️  Retrieved 22/208 → PMID 9100317
# ✔️  Retrieved 23/208 → PMID 16601648
# ✔️  Retrieved 24/208 → PMID 20013426
# ✔️  Retrieved 25/208 → PMID 18062943
# ⏳ Progress: 25/208 (12.0%)
# ✔️  Retrieved 26/208 → PMID 18368630
# ✔️  Retrieved 27/208 → PMID 21195144
# ✔️  Retrieved 28/208 → PMID 21254450
# ✔️  Retrieved 29/208 → PMID 20678186
# ✔️  Retrieved 30/208 → PMID 17019624
# ✔️  Retrieved 31/208 → PMID 1479049
# ✔️  Retrieved 32/208 → PMID 17938740
# ✔️  Retrieved 33/208 → PMID 17497416
# ✔️  Retrieved 34/208 → PMID 20734317
# ✔️  Retrieved 35/208 → PMID 18461502
# ✔️  Retrieved 36/208 → PMID 18349709
# ✔️  Retrieved 37/208 → PMID 25286049
# ✔️  Retrieved 38/208 → PMID 17352947
# ✔️  Retrieved 39/208 → PMID 6150139
# ✔️  Retrieved 40/208 → PMID 17822346
# ✔️  Retrieved 41/208 → PMID 9344057
# ✔️  Retrieved 42/208 → PMID 18929414
# ✔️  Retrieved 43/208 → PMID 17688650
# ✔️  Retrieved 44/208 → PMID 18445737
# ✔️  Retrieved 45/208 → PMID 16108456
# ✔️  Retrieved 46/208 → PMID 25051312
# ✔️  Retrieved 47/208 → PMID 15068403
# ✔️  Retrieved 48/208 → PMID 19267885
# ✔️  Retrieved 49/208 → PMID 16160627
# ✔️  Retrieved 50/208 → PMID 18405062
# ⏳ Progress: 50/208 (24.0%)
# ✔️  Retrieved 51/208 → PMID 17069545
# ✔️  Retrieved 52/208 → PMID 8570775
# ✔️  Retrieved 53/208 → PMID 16730335
# ✔️  Retrieved 54/208 → PMID 17485188
# ✔️  Retrieved 55/208 → PMID 18316065
# ✔️  Retrieved 56/208 → PMID 22537663
# ✔️  Retrieved 57/208 → PMID 22796576
# ✔️  Retrieved 58/208 → PMID 16494569
# ✔️  Retrieved 59/208 → PMID 19519261
# ✔️  Retrieved 60/208 → PMID 11476129
# ✔️  Retrieved 61/208 → PMID 30894343
# ✔️  Retrieved 62/208 → PMID 15994720
# ✔️  Retrieved 63/208 → PMID 20603192
# ✔️  Retrieved 64/208 → PMID 24781735
# ✔️  Retrieved 65/208 → PMID 18056831
# ✔️  Retrieved 66/208 → PMID 16920077
# ✔️  Retrieved 67/208 → PMID 19013209
# ✔️  Retrieved 68/208 → PMID 6502317
# ✔️  Retrieved 69/208 → PMID 19211157
# ✔️  Retrieved 70/208 → PMID 21156395
# ✔️  Retrieved 71/208 → PMID 24676906
# ✔️  Retrieved 72/208 → PMID 16818868
# ✔️  Retrieved 73/208 → PMID 19393386
# ✔️  Retrieved 74/208 → PMID 16401163
# ✔️  Retrieved 75/208 → PMID 17157402
# ⏳ Progress: 75/208 (36.1%)
# ✔️  Retrieved 76/208 → PMID 17150311
# ✔️  Retrieved 77/208 → PMID 19473900
# ✔️  Retrieved 78/208 → PMID 12806493
# ✔️  Retrieved 79/208 → PMID 24284360
# ✔️  Retrieved 80/208 → PMID 18080171
# ✔️  Retrieved 81/208 → PMID 28316773
# ✔️  Retrieved 82/208 → PMID 23665938
# ✔️  Retrieved 83/208 → PMID 17929164
# ✔️  Retrieved 84/208 → PMID 33991534
# ✔️  Retrieved 85/208 → PMID 16919138
# ✔️  Retrieved 86/208 → PMID 32661462
# ✔️  Retrieved 87/208 → PMID 12368987
# ✔️  Retrieved 88/208 → PMID 36516674
# ✔️  Retrieved 89/208 → PMID 29427782
# ✔️  Retrieved 90/208 → PMID 2606882
# ✔️  Retrieved 91/208 → PMID 32428529
# ✔️  Retrieved 92/208 → PMID 29121345
# ✔️  Retrieved 93/208 → PMID 15246500
# ✔️  Retrieved 94/208 → PMID 33765546
# ✔️  Retrieved 95/208 → PMID 20633039
# ✔️  Retrieved 96/208 → PMID 32073305
# ✔️  Retrieved 97/208 → PMID 16609825
# ✔️  Retrieved 98/208 → PMID 35365720
# ✔️  Retrieved 99/208 → PMID 16897403
# ✔️  Retrieved 100/208 → PMID 25874075
# ⏳ Progress: 100/208 (48.1%)
# ✔️  Retrieved 101/208 → PMID 19755133
# ✔️  Retrieved 102/208 → PMID 39559191
# ✔️  Retrieved 103/208 → PMID 9028057
# ✔️  Retrieved 104/208 → PMID 35802248
# ✔️  Retrieved 105/208 → PMID 20423563
# ✔️  Retrieved 106/208 → PMID 37357844
# ✔️  Retrieved 107/208 → PMID 31554142
# ✔️  Retrieved 108/208 → PMID 12195231
# ✔️  Retrieved 109/208 → PMID 16648008
# ✔️  Retrieved 110/208 → PMID 18985861
# ✔️  Retrieved 111/208 → PMID 33982067
# ✔️  Retrieved 112/208 → PMID 8768340
# ✔️  Retrieved 113/208 → PMID 18361446
# ✔️  Retrieved 114/208 → PMID 17207275
# ✔️  Retrieved 115/208 → PMID 15820420
# ✔️  Retrieved 116/208 → PMID 16239862
# ✔️  Retrieved 117/208 → PMID 27703770
# ✔️  Retrieved 118/208 → PMID 10360298
# ✔️  Retrieved 119/208 → PMID 16846101
# ✔️  Retrieved 120/208 → PMID 28569757
# ✔️  Retrieved 121/208 → PMID 15492353
# ✔️  Retrieved 122/208 → PMID 15930063
# ✔️  Retrieved 123/208 → PMID 18278980
# ✔️  Retrieved 124/208 → PMID 37207798
# ✔️  Retrieved 125/208 → PMID 15650499
# ⏳ Progress: 125/208 (60.1%)
# ✔️  Retrieved 126/208 → PMID 16297937
# ✔️  Retrieved 127/208 → PMID 16139734
# ✔️  Retrieved 128/208 → PMID 20576582
# ✔️  Retrieved 129/208 → PMID 18766980
# ✔️  Retrieved 130/208 → PMID 15794725
# ✔️  Retrieved 131/208 → PMID 17069546
# ✔️  Retrieved 132/208 → PMID 15747750
# ✔️  Retrieved 133/208 → PMID 7512516
# ✔️  Retrieved 134/208 → PMID 25477793
# ✔️  Retrieved 135/208 → PMID 19460635
# ✔️  Retrieved 136/208 → PMID 18940202
# ✔️  Retrieved 137/208 → PMID 31664451
# ✔️  Retrieved 138/208 → PMID 18315450
# ✔️  Retrieved 139/208 → PMID 10958654
# ✔️  Retrieved 140/208 → PMID 27895322
# ✔️  Retrieved 141/208 → PMID 30180205
# ✔️  Retrieved 142/208 → PMID 16948927
# ✔️  Retrieved 143/208 → PMID 12607287
# ✔️  Retrieved 144/208 → PMID 15132762
# ✔️  Retrieved 145/208 → PMID 18395759
# ✔️  Retrieved 146/208 → PMID 8157157
# ✔️  Retrieved 147/208 → PMID 20674424
# ✔️  Retrieved 148/208 → PMID 9672054
# ✔️  Retrieved 149/208 → PMID 35594946
# ✔️  Retrieved 150/208 → PMID 19056591
# ⏳ Progress: 150/208 (72.1%)
# ✔️  Retrieved 151/208 → PMID 16919137
# ✔️  Retrieved 152/208 → PMID 18685284
# ✔️  Retrieved 153/208 → PMID 23516405
# ✔️  Retrieved 154/208 → PMID 36535311
# ✔️  Retrieved 155/208 → PMID 24675092
# ✔️  Retrieved 156/208 → PMID 19221690
# ✔️  Retrieved 157/208 → PMID 29478806
# ✔️  Retrieved 158/208 → PMID 21398041
# ✔️  Retrieved 159/208 → PMID 19232924
# ✔️  Retrieved 160/208 → PMID 17069544
# ✔️  Retrieved 161/208 → PMID 17507914
# ✔️  Retrieved 162/208 → PMID 18026891
# ✔️  Retrieved 163/208 → PMID 23055421
# ✔️  Retrieved 164/208 → PMID 28921105
# ✔️  Retrieved 165/208 → PMID 17069550
# ✔️  Retrieved 166/208 → PMID 10888601
# ✔️  Retrieved 167/208 → PMID 17400887
# ✔️  Retrieved 168/208 → PMID 27548254
# ✔️  Retrieved 169/208 → PMID 18558336
# ✔️  Retrieved 170/208 → PMID 41205789
# ✔️  Retrieved 171/208 → PMID 19368416
# ✔️  Retrieved 172/208 → PMID 9229261
# ✔️  Retrieved 173/208 → PMID 8808733
# ✔️  Retrieved 174/208 → PMID 16379507
# ✔️  Retrieved 175/208 → PMID 16917939
# ⏳ Progress: 175/208 (84.1%)
# ✔️  Retrieved 176/208 → PMID 33712018
# ✔️  Retrieved 177/208 → PMID 21388746
# ✔️  Retrieved 178/208 → PMID 30452514
# ✔️  Retrieved 179/208 → PMID 17630868
# ✔️  Retrieved 180/208 → PMID 19265183
# ✔️  Retrieved 181/208 → PMID 29120534
# ✔️  Retrieved 182/208 → PMID 39194383
# ✔️  Retrieved 183/208 → PMID 11263692
# ✔️  Retrieved 184/208 → PMID 15543515
# ✔️  Retrieved 185/208 → PMID 30409451
# ✔️  Retrieved 186/208 → PMID 29553459
# ✔️  Retrieved 187/208 → PMID 34453960
# ✔️  Retrieved 188/208 → PMID 29309796
# ✔️  Retrieved 189/208 → PMID 18177632
# ✔️  Retrieved 190/208 → PMID 16904652
# ✔️  Retrieved 191/208 → PMID 18387724
# ✔️  Retrieved 192/208 → PMID 33497755
# ✔️  Retrieved 193/208 → PMID 24803368
# ✔️  Retrieved 194/208 → PMID 34781058
# ✔️  Retrieved 195/208 → PMID 33906504
# ✔️  Retrieved 196/208 → PMID 25252317
# ✔️  Retrieved 197/208 → PMID 9808916
# ✔️  Retrieved 198/208 → PMID 10933118
# ✔️  Retrieved 199/208 → PMID 18752063
# ✔️  Retrieved 200/208 → PMID 18396377
# ⏳ Progress: 200/208 (96.2%)
# ✔️  Retrieved 201/208 → PMID 17069543
# ✔️  Retrieved 202/208 → PMID 14585753
# ✔️  Retrieved 203/208 → PMID 21115397
# ✔️  Retrieved 204/208 → PMID 15205966
# ✔️  Retrieved 205/208 → PMID 32526256
# ✔️  Retrieved 206/208 → PMID 16417856
# ✔️  Retrieved 207/208 → PMID 23613074
# ✔️  Retrieved 208/208 → PMID 29298162
# DONE! All available PMIDs retrieved.
# Total records downloaded: 208
#        pmid                                              title  \
# 0  20562626  Perinatal exposure to hazardous air pollutants...
# 1   3709993  Effects of fenfluramine on eight outpatients w...
# 2  35254616  Autism spectrum disorder-like behavior induced...
# 3  30816183  Sex Differences in the Effects of Prenatal Bis...
# 4  36113784  Prenatal, but not postnatal exposure to chlorp...
#
#                                             abstract  \
# 0  Hazardous air pollutants are plausible candida...
# 1  Fenfluramine was administered to eight autisti...
# 2  Autism spectrum disorders (ASD), also known as...
# 3  Autism spectrum disorder (ASD) is a neurodevel...
# 4  The balance between excitatory and inhibitory ...
#
#                                              xml_raw
# 0  <?xml version="1.0" ?>\n<!DOCTYPE PubmedArticl...
# 1  <?xml version="1.0" ?>\n<!DOCTYPE PubmedArticl...
# 2  <?xml version="1.0" ?>\n<!DOCTYPE PubmedArticl...
# 3  <?xml version="1.0" ?>\n<!DOCTYPE PubmedArticl...
# 4  <?xml version="1.0" ?>\n<!DOCTYPE PubmedArticl...

# %%
pubmed_dataset=df

# %%
pubmed_dataset=pubmed_dataset[['pmid', 'abstract']]
pubmed_dataset
# Out:
#          pmid                                           abstract
# 0    20562626  Hazardous air pollutants are plausible candida...
# 1     3709993  Fenfluramine was administered to eight autisti...
# 2    35254616  Autism spectrum disorders (ASD), also known as...
# 3    30816183  Autism spectrum disorder (ASD) is a neurodevel...
# 4    36113784  The balance between excitatory and inhibitory ...
# ..        ...                                                ...
# 203  15205966  There is great evidence in recent years that o...
# 204  32526256  The manifestations of autism spectrum disorder...
# 205  16417856  Gestational and genetic factors can contribute...
# 206  23613074  Valproate is used for the treatment of epileps...
# 207  29298162  Emerging work has examined neurodevelopmental ...
#
# [208 rows x 2 columns]

# %%
pubmed_dataset = pubmed_dataset[
    pubmed_dataset["abstract"].astype(str).str.strip() != ""
]

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk import pos_tag

# Downloads
nltk.download("punkt")
nltk.download("averaged_perceptron_tagger")
nltk.download("wordnet")

lemmatizer = WordNetLemmatizer()

# Function to convert nltk pos tags to wordnet tags
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# Tokenize + POS tag + Lemmatize
pubmed_dataset["tokens"] = (
    pubmed_dataset["abstract"]
        .astype(str)
        .str.lower()
        .apply(word_tokenize)
        .apply(lambda words: pos_tag(words))
        .apply(lambda tagged: [
            lemmatizer.lemmatize(w, get_wordnet_pos(tag))
            for w, tag in tagged
        ])
)
# Out:
# [nltk_data] Downloading package punkt to /home/giannis-
# [nltk_data]     charalampopoulos/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/giannis-charalampopoulos/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/giannis-
# [nltk_data]     charalampopoulos/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /tmp/ipykernel_302434/988891669.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pubmed_dataset["tokens"] = (

# %%
import re

def custom_tokenize(text):
    # keep numbers like 15,000 or 3.5e10 as one token
    pattern = r'\d[\d,\.]*|\w+'
    return re.findall(pattern, text.lower())

# %%
pubmed_dataset["tokens"] = pubmed_dataset["tokens"].apply(
    lambda lst: [t for t in lst if any(c.isalnum() for c in t)]
)
# Out:
# /tmp/ipykernel_302434/3246752615.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pubmed_dataset["tokens"] = pubmed_dataset["tokens"].apply(

# %%
pubmed_dataset=pubmed_dataset.rename(columns={"tokens":"Text"})

# %%
pubmed_dataset_processed=pubmed_dataset[["pmid", "Text"]]

# %%
merged = pd.merge(
    pubmed_dataset_processed,
    disease_chems,
    left_on="pmid",
    right_on="PubMedIDs",
    how="inner"
)

# %%
import pandas as pd
import math
from collections import Counter

# ===================== DATA =====================
final_dataset = merged  # your dataframe

# ===================== RELATION PATTERNS =====================

RELATION_PATTERNS = [
    # Strong causal
    ["cause"], ["causes"], ["caused"],
    ["induce"], ["induces"], ["induced"],
    ["lead", "to"], ["leads", "to"],
    ["trigger"], ["triggers"],

    # Risk-related
    ["increase", "risk"], ["increases", "risk"],
    ["risk", "of"],

    # Associative (explicit)
    ["associated"], ["associated", "with"],
    ["linked"], ["linked", "to"], ["linked", "with"],
    ["related"], ["related", "to"],
    ["correlated", "with"],

    # Biomedical implicit language
    ["involved", "in"],
    ["implicated", "in"],
    ["role", "in"],
    ["plays", "a", "role", "in"],
    ["affects"], ["affect"],
    ["altered"], ["reduced"], ["increased"]
]

# ===================== WEIGHT FUNCTION =====================

def get_weight(pattern):
    base = 1.0 + (0.4 * (len(pattern) - 1))
    text = " ".join(pattern)

    if any(w in text for w in ["cause", "induce", "lead", "trigger"]):
        return base + 2.0
    if "risk" in text:
        return base + 1.5
    if any(w in text for w in ["associated", "linked", "related", "correlated"]):
        return base + 1.0
    return base + 0.5  # biomedical implicit relations

PATTERN_WEIGHTS = {tuple(p): get_weight(p) for p in RELATION_PATTERNS}

# ===================== EXACT PATTERN MATCHING =====================

def match_exact_patterns(tokens):
    score = 0.0
    for pattern, weight in PATTERN_WEIGHTS.items():
        n = len(pattern)
        for i in range(len(tokens) - n + 1):
            if tuple(tokens[i:i+n]) == pattern:
                score += weight
    return score

# ===================== WINDOW-BASED MATCHING (±10 tokens) =====================

RELATION_KEYWORDS = {
    "cause", "causes", "induce", "induces", "risk",
    "associated", "linked", "related", "involved",
    "implicated", "affects", "altered", "reduced", "increased"
}

def match_window_patterns(tokens, window=10):
    score = 0.0
    for i, token in enumerate(tokens):
        if token in RELATION_KEYWORDS:
            left = max(0, i - window)
            right = min(len(tokens), i + window + 1)
            context = tokens[left:right]

            # Require meaningful biomedical context
            if len(context) > 3:
                score += 0.7
    return score

# ===================== BUILD COUNTS =====================

pair_counts = Counter()
pair_pattern_score = Counter()

for _, row in final_dataset.iterrows():
    chem = row["ChemicalName"]
    dis = row["DiseaseName"]
    tokens = row["Text"]
    pair = (chem, dis)

    pair_counts[pair] += 1

    exact_score = match_exact_patterns(tokens)
    window_score = match_window_patterns(tokens)

    pair_pattern_score[pair] += exact_score + window_score

# ===================== FINAL RESULTS =====================

rows = []
for (chem, dis), count in pair_counts.items():
    pattern_score = pair_pattern_score[(chem, dis)]

    evidence_score = math.log(pattern_score + 1) * math.log(count + 2)

    rows.append({
        "ChemicalName": chem,
        "DiseaseName": dis,
        "CoOccurrences": count,
        "WeightedPatternEvidence": round(pattern_score, 2),
        "EvidenceScore": round(evidence_score, 2)
    })

result = pd.DataFrame(rows).sort_values("EvidenceScore", ascending=False)
print(result)
# Out:
#                ChemicalName                             DiseaseName  \
# 6             Valproic Acid                       Autistic Disorder
# 15              Risperidone                       Autistic Disorder
# 3             Valproic Acid                Autism Spectrum Disorder
# 28                Serotonin                       Autistic Disorder
# 2    Diethylhexyl Phthalate                Autism Spectrum Disorder
# ..                      ...                                     ...
# 124               Neopterin                       Autistic Disorder
# 123              Biopterins                       Autistic Disorder
# 122              Topiramate  Child Development Disorders, Pervasive
# 114             Mirtazapine                       Autistic Disorder
# 181  perfluorooctanoic acid                Autism Spectrum Disorder
#
#      CoOccurrences  WeightedPatternEvidence  EvidenceScore
# 6               81                    384.6          26.31
# 15              78                    134.7          21.52
# 3               26                    252.8          18.45
# 28              21                     49.2          12.28
# 2               10                    116.6          11.85
# ..             ...                      ...            ...
# 124              3                      0.0           0.00
# 123              3                      0.0           0.00
# 122              1                      0.0           0.00
# 114              3                      0.0           0.00
# 181              2                      0.0           0.00
#
# [182 rows x 5 columns]

# %%
chemicals_to_check = ["Permethrin", "Glutathione", "Thimerosal"]

filtered_check = result[result["ChemicalName"].isin(chemicals_to_check)]

print(filtered_check)
# Out:
#     ChemicalName               DiseaseName  CoOccurrences  \
# 45   Glutathione         Autistic Disorder             15
# 75    Permethrin  Autism Spectrum Disorder              2
# 140   Thimerosal         Autistic Disorder              3
#
#      WeightedPatternEvidence  EvidenceScore
# 45                      16.8           8.16
# 75                      21.6           4.32
# 140                     11.1           4.01

# %%
filtered_check
# Out:
#     ChemicalName               DiseaseName  CoOccurrences  \
# 45   Glutathione         Autistic Disorder             15
# 75    Permethrin  Autism Spectrum Disorder              2
# 140   Thimerosal         Autistic Disorder              3
#
#      WeightedPatternEvidence  EvidenceScore
# 45                      16.8           8.16
# 75                      21.6           4.32
# 140                     11.1           4.01
